# %%
import grn_learn as g
import numpy as np
import pandas as pd
import networkx

# %%
org = 'paeru'
paeru_path = '~/Documents/uni/bioinfo/data/paeru/'

# %%
tf_trn = pd.read_csv(paeru_path + 'paeru_tf_tf_net.csv')

trn = pd.read_csv(paeru_path + 'paeru-trn.csv')

# %%
# Lowercase gene names for both datasets
tf_trn.TF = tf_trn.TF.apply(lambda x: x.lower())
tf_trn.TG = tf_trn.TG.apply(lambda x: x.lower())

trn.TF = trn.TF.apply(lambda x: x.lower())
trn.TG = trn.TG.apply(lambda x: x.lower())
