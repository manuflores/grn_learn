# %% [markdown]
# ### GRN Learn
#
# 1. ~~check if TFs in a module are correlated~~ : done
#
# 1.1. ~~e.g. genes in an operon~~ <br> : they are corr
# 1.2.~~genes in a module SoxR and SoxS~~ <br> : not corr
# 1.3. ~~SoxR and OxyR~~ <br> : not corr
# 1.4. ~~Make a generalizable function to get any pair of genes, or go further~~ <br>: done, have to make interactive... we could use hover on data (prot, fit) where features are interpretable..
# 1.5. Make a generalizable function to get a Gridmap plot of any four or five genes: check what's the limit.

# %% [markdown]
# ### Unsupervised learning : dim reduction and clustering
#
# 2. ~~Make umap of the whole dataset~~ <br>
#
# If the data looks clustery... which it does!
#
# 2.0.1 Make clustering (bayesian gaussian mixture model) in the UMAP dimensions and see if the clusters are similar to what we get from the network. <br>
#
# Mini-project on clustering evaluation :
#
# Say I have a set of labels corresponding to the clusters of the TF-TF TRN: have to get... maybe from the data prep ntoebook
#
# What’s the mutual information of the label set with itself.
#
# Diverging... If we were to use the spectral biclustering case, make a function to automatically choose *k*.
#
# What’s the mutual information of the label set changing cluster numbers say 1 for 2 and 2 for
#
# What’s the variation of information in both of these cases.
#
# Then ask: given a dataset, say Weissman Or TnSeq ir Colombos with the first two PCs/UMAPs: which clustering algorithm gives the best score ?
#
# 2.1 Make UMAP of only the TRN <br> : done
# 2.2 Make supervised umap of the TRN color coding the clusters from the TF - TF network <br>
# 2.3 Make semisupervised UMAP of all of the genes. **Caveat, have to figure out a way to automatically get a single cluster label for each gene. ** We would have to do something like
#
# <br>
#
# 3.0 If the UMAP on the whole dataset works swiftly, we could then apply a freaking bayesian mixture model to the TRN data only, and then use those labels as the training data for the classifier... this way we get the nifty representation from the unsupervised case, a single label for the real clusters in the latent space and only then we have a nice way to learn using multilabel classifiers  <br>
#
# 3.0.1 The more data the better: What happens if we apply the UMAP to the fitness or the proteomics data, what happens if we mix the fit + proteomics, what if we do all three fit + expression + proteomics ? <br>
#
#
# Only if everything else fails in the unsupervised case ...

# %% [markdown]
# ### TRN AI
#
# 3. Train in reduced space of PCA dimensions : check the dimensionality with the % of variance explained plot. <br>
#
# Could we use a simple logistic regression ? before going for the more complicated keras models ? <br>
#
# Train on reduced space by AE + keras clf <br>
#
# Train on reconstructed space by VAE + keras clf <br>
#
# Train reconstructed space by convolutional VAE  + normal net <br>
#
# Train reconstructed space by convolutional VAE  + conv net <br>
#
# Train reconstructed space by denoising VAE  + the best net <br>
#
# Then with the best model, add more data and see what happens...
#
#
# 4. VAE : check paper and say explicitly why VAE? Interpolation, non-linear dimension reduction de-noising.
# 4.1. UMAP of VAE latent space
#
# 5. Keras deep net and Keras CNN https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53
#
# 6. Cross validation
#
# 7. maybe extract the clusters from the data itself and then train with that ? linked to 2.0.1
#
# clustering / sup learning of the TFBSs of the TFs
#
# • Check greene lab pubs
#
# http://www.greenelab.com/publications
#
# https://www.biorxiv.org/content/biorxiv/early/2019/09/26/573782.full.pdf
#
# https://www.biorxiv.org/content/biorxiv/early/2017/03/21/118349.full.pdf
